# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('/Titanic-Dataset.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))


data['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot(x='Survived', data=data, ax=ax[1])
ax[1].set_title('Survived')


plt.show()

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')


sns.countplot(x='Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead
plt.show()

# %%
ct = pd.crosstab(data.Pclass, data.Survived, margins=True)


ct.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6f0e2_row0_col0, #T_6f0e2_row1_col1, #T_6f0e2_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6f0e2_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_6f0e2_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_6f0e2_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_6f0e2_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_6f0e2_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_6f0e2_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_6f0e2_row3_col0, #T_6f0e2_row3_col1, #T_6f0e2_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f0e2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_6f0e2_level0_col0" class="col_heading level0 col0" >0</th>
# ...

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

data['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count)
sns.countplot(x='Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead')


plt.show()

# %%
ct = pd.crosstab([data.Sex, data.Survived], data.Pclass, margins=True)


ct.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_7680e_row0_col0, #T_7680e_row0_col1, #T_7680e_row0_col3, #T_7680e_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7680e_row0_col2, #T_7680e_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_7680e_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_7680e_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_7680e_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_7680e_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_7680e_row2_col1, #T_7680e_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_7680e_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_7680e_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_7680e_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_7680e_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot(x="Pclass", y="Age", hue="Survived", data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
sns.violinplot(x="Sex", y="Age", hue="Survived", data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))


plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 10))


data[data['Survived'] == 0].Age.plot.hist(ax=ax[0], bins=20, edgecolor='black', color='red')
ax[0].set_title('Survived = 0')
x_ticks = list(range(0, 85, 5))
ax[0].set_xticks(x_ticks)


data[data['Survived'] == 1].Age.plot.hist(ax=ax[1], color='green', bins=20, edgecolor='black')
ax[1].set_title('Survived = 1')
ax[1].set_xticks(x_ticks)
