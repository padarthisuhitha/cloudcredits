# %% [markdown]
# <a href="https://colab.research.google.com/github/padarthisuhitha/cloudcredits/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filena)

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/content/archive (1).zip')
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.shape
# Out:
# (148, 7)

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
df = df.drop(['url', 'address', 'phone', 'menu_item', 'dish_liked', 'reviews_list'], axis=1, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (148, 7)

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5'],
#       dtype=object)

# %%
def handlerate(value):
    if(value=='NEW' or value=='-'):
        return np.nan
    else:
        value = str(value).split('/')
        value = value[0]
        return float(value)

df['rate'] = df['rate'].apply(handlerate)
df['rate'].head()
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: float64

# %%
df['rate'].fillna(df['rate'].mean(), inplace = True)
df['rate'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %%
df.dropna(inplace = True)
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.rename(columns = {'approx_cost(for two people)':'Cost2plates', 'listed_in(type)':'Type'}, inplace = True)
df.head()
# Out:
#                     name online_order book_table  rate  votes  Cost2plates  \
# 0                  Jalsa          Yes        Yes   4.1    775          800
# 1         Spice Elephant          Yes         No   4.1    787          800
# 2        San Churro Cafe          Yes         No   3.8    918          800
# 3  Addhuri Udupi Bhojana           No         No   3.7     88          300
# 4          Grand Village           No         No   3.8    166          600
#
#      Type
# 0  Buffet
# 1  Buffet
# 2  Buffet
# 3  Buffet
# 4  Buffet

# %%
if 'location' in df.columns:
    print(df['location'].unique())  # Display unique location values
else:
    print("Column 'location' does not exist in the DataFrame.")
# Out:
# Column 'location' does not exist in the DataFrame.

# %%
def handlecomma(value):
    value = str(value)
    if ',' in value:
        value = value.replace(',', '')
        return float(value)
    else:
        return float(value)

df['Cost2plates'] = df['Cost2plates'].apply(handlecomma)
df['Cost2plates'].unique()
# Out:
# array([800., 300., 600., 700., 550., 500., 450., 650., 400., 900., 200.,
#        750., 150., 850., 100., 350., 250., 950.])

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  Cost2plates  \
# 0                  Jalsa          Yes        Yes   4.1    775        800.0
# 1         Spice Elephant          Yes         No   4.1    787        800.0
# 2        San Churro Cafe          Yes         No   3.8    918        800.0
# 3  Addhuri Udupi Bhojana           No         No   3.7     88        300.0
# 4          Grand Village           No         No   3.8    166        600.0
#
#      Type
# 0  Buffet
# 1  Buffet
# 2  Buffet
# 3  Buffet
# 4  Buffet

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if 'location' in df.columns:
    plt.figure(figsize=(16, 10))


    ax = sns.countplot(x=df['location'], order=df['location'].value_counts().index)


    plt.xticks(rotation=90)


    plt.title("Count of Restaurants per Location", fontsize=14)
    plt.xlabel("Location", fontsize=12)
    plt.ylabel("Count", fontsize=12)

    plt.show()
else:
    print("Column 'location' does not exist in the DataFrame.")
# Out:
# Column 'location' does not exist in the DataFrame.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['online_order'], palette = 'inferno')
# Out:
# <Axes: xlabel='count', ylabel='online_order'>

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['book_table'], palette = 'rainbow')
# Out:
# <Axes: xlabel='count', ylabel='book_table'>

# %%
plt.figure(figsize = (6,6))
sns.boxplot(x = 'online_order', y = 'rate', data = df)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %%
plt.figure(figsize = (6,6))
sns.boxplot(x = 'book_table', y = 'rate', data = df)
# Out:
# <Axes: xlabel='book_table', ylabel='rate'>

# %%
plt.figure(figsize = (14, 8))
sns.boxplot(x = 'Type', y = 'rate', data = df, palette = 'inferno')
# Out:
# <Axes: xlabel='Type', ylabel='rate'>
